# %% [markdown]
# # molecule docking using Gnina
#
# #### Training data:
# - Perturbagens with known structures and protein targets
# - Gene expression changes of cell lines when treated with certain perturbagen
#
# #### Output:
# - 2D graph structures of new molecules
#
# ```Can we compare the

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
import pickle
from tqdm import tqdm
import os
from collections import defaultdict
import re

# %%
with open("/data/ongh0068/l1000/l1000_biaae/protein_target_to_l1000_smiles.pkl", 'rb') as f:
    meta_data = pickle.load(f)

inv_meta_data = {}
for k,v in meta_data.items():
    for x in v:
        inv_meta_data.setdefault(x, []).append(k)
        
inv_meta_data
# Out:
# {'CS(=O)c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)cc1': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'EGFR',
#   'MTOR'],
#  'Cn1cc(C2=C(c3cn(CCCSC(=N)N)c4ccccc34)C(=O)NC2=O)c2ccccc21': ['AKT1',
#   'SMAD3'],
#  'CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1': ['AKT1', 'AKT2', 'AURKB'],
#  'O=c1cc(N2CCOCC2)oc2c(-c3ccccc3)cccc12': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'MTOR',
#   'PIK3CA',
#   'TP53'],
#  'O=C1NC(=O)C(c2c[nH]c3ccccc23)=C1c1c[nH]c2ccccc12': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'MTOR'],
#  'COc1cc2ncnc(Nc3ccc(Oc4ccccc4)cc3)c2cc1OC': ['AKT1', 'AKT2', 'MTOR'],
#  'O=C(c1ccccc1)c1ccc(N2CCOCC2)cc1O': ['AKT1', 'AKT2', 'AURKB', 'MTOR'],
#  'C#Cc1cccc(Nc2ncnc3cc(OCCOC)c(OCCOC)cc23)c1': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'EGFR'],
#  'O=C(Nc1cccc(Cl)c1)Nc1ncc(CCNc2ncnc3ccsc23)s1': ['AKT1', 'AKT2', 'EGFR'],
#  'CN1CCC(c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)C(O)C1': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'EGFR'],
#  'O=[N+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)cc1': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'MTOR',
#   'TP53'],
#  'Cn1cc(C=C2C(=O)Nc3cccnc32)c2ccccc21': ['AKT2'],
#  'COC(C(=O)N1Cc2[nH]nc(NC(=O)c3ccc(N4CCN(C)CC4)cc3)c2C1)c1ccccc1': ['AKT2'],
#  'O=c1cc(N2CCOCC2)oc2c1ccc1ccccc12': ['AKT2', 'AURKB', 'MTOR'],
#  'COc1cc(OC)c(C=C2C(=O)Nc3ccccc32)c(OC)c1': ['AKT2', 'AURKB'],
#  'Nc1nc(Nc2ccc(S(N)(=O)=O)cc2)nn1C(=O)c1c(F)cccc1F': ['AKT2', 'AURKB', 'MTOR'],
#  'N#CC(=Cc1ccc(O)c(O)c1)C(=O)NCc1ccccc1': ['AKT2'],
#  'COc1cc(Nc2ncc(F)c(Nc3ccc4c(n3)NC(=O)C(C)(C)O4)n2)cc(OC)c1OC': ['AKT2'],
#  'Oc1ccc(Nc2nc(-c3ccc(Cl)cc3)cs2)cc1': ['AKT2', 'MTOR'],
#  'O=c1cc(N2CCNCC2)oc2c(-c3ccccc3)cccc12': ['AKT2', 'MTOR'],
#  'CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1': ['AKT2',
#   'MTOR',
#   'SMAD3',
#   'TP53'],
#  'O=c1cc(-c2cccc3c2Sc2ccccc2S3)oc(N2CCOCC2)c1': ['AKT2', 'MTOR'],
#  'O=S(=O)(NCCNCC=Cc1ccc(Br)cc1)c1cccc2cnccc12': ['AKT2'],
#  'CNC(=O)c1ccccc1Sc1ccc2c(C=Cc3ccccn3)n[nH]c2c1': ['AKT2'],
#  'CC1CCN(C(=O)CC#N)CC1N(C)c1ncnc2[nH]ccc12': ['AKT2'],
#  'CN(C)CCCn1cc(C2=C(c3c[nH]c4ccccc34)C(=O)NC2=O)c2ccccc21': ['AKT2', 'MTOR'],
#  'O=C1NC(=O)c2cc(Nc3ccc(F)cc3)c(Nc3ccc(F)cc3)cc21': ['AKT2', 'MTOR'],
#  'CC(C)N(CCC(=O)c1ccc2ccccc2c1)Cc1ccccc1': ['AKT2', 'AURKB', 'MTOR'],
#  'Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(CCO)CC2)n1': ['AKT2', 'MTOR'],
#  'CCCCc1c(-c2ccc(OC)cc2)[nH]c2nccnc12': ['AKT2', 'MTOR'],
#  'NC(=O)Nc1sc(-c2ccc(F)cc2)cc1C(N)=O': ['AKT2', 'MTOR'],
#  'CCc1nc(-c2cccc(C)c2)c(-c2ccnc(NC(=O)c3ccccc3)c2)s1': ['AKT2', 'AURKB'],
#  'COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c2cc1OC': ['AKT2', 'MTOR'],
#  'O=C(CCCc1ccc(-c2ccccc2F)cc1)Nc1ccc(O)cc1': ['AKT2', 'MTOR'],
#  'c1cc(-c2cnn3cc(-c4ccc(OCCN5CCCCC5)cc4)cnc23)ccn1': ['AKT2', 'MTOR'],
#  'Oc1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)cc1': ['AKT2', 'MTOR'],
#  'Cc1[nH]c(C=C2C(=O)Nc3ccccc32)c(C)c1CCC(=O)O': ['AKT2'],
#  'COc1cccc(-c2cc(=O)c3ccccc3o2)c1N': ['AKT2', 'MTOR', 'TP53'],
#  'CCN(CCO)CCCOc1ccc2c(Nc3cc(CC(=O)Nc4cccc(F)c4)[nH]n3)ncnc2c1': ['AKT2'],
#  'COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN1CCOCC1': ['AKT2'],
#  'CCC1C(=O)N(C)c2cnc(Nc3ccc(C(=O)NC4CCN(C)CC4)cc3OC)nc2N1C1CCCC1': ['AKT2'],
#  'COc1ccc(Cl)cc1NC(=O)Nc1cc(C)nc2ccccc12': ['AKT2', 'MTOR'],
#  'COc1ccc(CNC(=O)Nc2ncc([N+](=O)[O-])s2)cc1': ['AKT2', 'MTOR'],
#  'Oc1cccc(-c2nc(N3CCOCC3)c3oc4ncccc4c3n2)c1': ['AKT2', 'MTOR', 'PIK3CA'],
#  'COc1cc2ncnc(Nc3cccc(Cl)c3)c2cc1OC': ['AKT2',
#   'AURKB',
#   'EGFR',
#   'MTOR',
#   'SMAD3'],
#  'CCN(CC)CCCCN1c2ccccc2Oc2ccc(Cl)cc21': ['AKT2', 'AURKB', 'MTOR'],
#  'COc1cc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)cccc2OC)=NC3)ccc1C(=O)O': ['AKT2'],
#  'COc1cc2ncc(-c3ccccc3)nc2cc1OC': ['AKT2', 'MTOR'],
#  'O=S(=O)(c1cccc2cnccc12)N1CCCNCC1': ['AKT2', 'MTOR', 'SMAD3'],
#  'CC(Oc1cc(-c2cnn(C3CCNCC3)c2)cnc1N)c1c(Cl)ccc(F)c1Cl': ['AKT2', 'AURKB'],
#  'COc1ccc(C(=O)Nc2sc3c(c2C(N)=O)CCCC3)cc1OC': ['AKT2', 'AURKB', 'MTOR'],
#  'COc1nccc(-c2c(-c3ccc(F)cc3)ncn2C2CCC(O)CC2)n1': ['AKT2'],
#  'O=C(O)c1ccc(Nc2ncc3c(n2)-c2ccc(Cl)cc2C(c2c(F)cccc2F)=NC3)cc1': ['AKT2',
#   'AURKB'],
#  'CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1': ['AKT2'],
#  'COc1cc2c(Oc3ccc4[nH]c(C)cc4c3F)ncnc2cc1OCCCN1CCCC1': ['AKT2'],
#  'CNCc1ccc(-c2[nH]c3cc(F)cc4c3c2CCNC4=O)cc1': ['AKT2', 'AURKB'],
#  'COc1cc2ncn(-c3cc(OCc4ccccc4C(F)(F)F)c(C(N)=O)s3)c2cc1OC': ['AKT2', 'AURKB'],
#  'O=c1ncn2nc(Sc3ccc(F)cc3F)ccc2c1-c1c(Cl)cccc1Cl': ['AKT2'],
#  'Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1': ['AKT2',
#   'AURKB'],
#  'Nc1cccc(-c2cc3c(Oc4cccc(O)c4)ncnc3[nH]2)c1': ['AKT2', 'MTOR'],
#  'NC(=O)c1cccc(-c2cc(Nc3ccc(OC(F)(F)F)cc3)ncn2)c1': ['AKT2', 'MTOR'],
#  'Cc1ccc(F)c(NC(=O)Nc2ccc(-c3cccc4[nH]nc(N)c34)cc2)c1': ['AKT2'],
#  'CCN(CC)CCNC(=O)c1c(C)[nH]c(C=C2C(=O)Nc3ccc(F)cc32)c1C': ['AKT2'],
#  'CC1(O)CC(c2nc(-c3ccc4ccc(-c5ccccc5)nc4c3)c3c(N)nccn23)C1': ['AKT2'],
#  'COc1ccc(-c2cc3nccn3c(Nc3ncccc3C(N)=O)n2)cc1OC': ['AKT2', 'AURKB'],
#  'Cc1ccc(-n2nc(C(C)(C)C)cc2NC(=O)Nc2ccc(OCCN3CCOCC3)c3ccccc23)cc1': ['AKT2'],
#  'COc1ccc(-c2cnc3c(-c4ccsc4)cnn3c2)cc1': ['AKT2', 'AURKB', 'MTOR'],
#  'Cn1c(=O)n(-c2ccc(C(C)(C)C#N)cc2)c2c3cc(-c4cnc5ccccc5c4)ccc3ncc21': ['AURKB',
#   'MTOR',
#   'PIK3CA',
#   'SMAD3'],
#  'Cc1cnc(Nc2ccc(OCCN3CCCC3)cc2)nc1Nc1cccc(S(=O)(=O)NC(C)(C)C)c1': ['AURKB',
#   'PIK3CA'],
#  'CC(=O)c1c(C)c2cnc(Nc3ccc(N4CCNCC4)cn3)nc2n(C2CCCC2)c1=O': ['AURKB'],
#  'COc1cc2ncn(-c3cc(OCc4ccccc4S(C)(=O)=O)c(C#N)s3)c2cc1OC': ['AURKB'],
#  'C=CCn1c(=O)c2cnc(Nc3ccc(N4CCN(C)CC4)cc3)nc2n1-c1cccc(C(C)(C)O)n1': ['AURKB'],
#  'Cc1ccc(Nc2nccc(N(C)c3ccc4c(C)n(C)nc4c3)n2)cc1S(N)(=O)=O': ['AURKB'],
#  'O=C1NC(=O)c2cc(Nc3ccccc3)c(Nc3ccccc3)cc21': ['EGFR'],
#  'O=C(c1cc2ccccc2[nH]1)c1cc2cc(O)ccc2[nH]1': ['EGFR'],
#  'Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21': ['EGFR'],
#  'CC(=O)Nc1ccc(C(=O)Nc2cc(-c3cccs3)ccc2N)cc1': ['HDAC1'],
#  'Nc1ccccc1NC(=O)c1ccc(CNc2nccc(-c3cccnc3)n2)cc1': ['HDAC1'],
#  'Nc1ccccc1NC(=O)c1ccc(CNC(=O)OCc2cccnc2)cc1': ['HDAC1'],
#  'CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccccc3)CC2)cc1': ['MTOR'],
#  'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC': ['MTOR'],
#  'CNC(=O)Nc1ccc(-c2nc(N3CC4CCC(C3)O4)c3cnn(C4CCC5(CC4)OCCO5)c3n2)cc1': ['MTOR',
#   'PIK3CA'],
#  'CN1C2CCC1CC(OC(=O)c1c[nH]c3ccccc13)C2': ['MTOR'],
#  'O=c1cc(N2CCOCC2)oc2c(-c3cccc4c3sc3ccccc34)cccc12': ['MTOR', 'PIK3CA'],
#  'OC1(c2ccc(Cl)cc2)CCN(Cc2c[nH]c3ccccc23)CC1': ['MTOR'],
#  'Cc1cccc(CS(=O)(=O)c2ncc(Cl)c(C(=O)Nc3nnc(C(C)C)s3)n2)c1': ['MTOR', 'TP53'],
#  'OCCN1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1': ['MTOR', 'TP53'],
#  'COc1ccc(NC(=O)c2ccc(-c3ccc(-c4noc(C)n4)cc3C)cc2)cc1N1CCN(C)CC1': ['MTOR'],
#  'CC(C)c1ccc2c(c1)c(SC(C)(C)C)c(CC(C)(C)C(=O)O)n2Cc1ccc(Cl)cc1': ['MTOR',
#   'SMAD3',
#   'TP53'],
#  'O=C1c2c(O)ccc(O)c2C(=O)c2c(NCCNCCO)ccc(NCCNCCO)c21': ['MTOR',
#   'SMAD3',
#   'TP53'],
#  'COc1cc2nc(N3CCCN(C)CC3)nc(NC3CCN(Cc4ccccc4)CC3)c2cc1OC': ['MTOR', 'SMAD3'],
#  'Cc1ccc(CS(=O)(=O)c2ncc(Cl)c(C(=O)Nc3nnc(C(C)C)s3)n2)cc1': ['MTOR', 'TP53'],
#  'O=C(Nc1ccc([N+](=O)[O-])cc1Cl)c1cc(Cl)ccc1O': ['MTOR', 'TP53'],
#  'CC(C)(C)c1cc(C=C(C#N)C#N)cc(C(C)(C)C)c1O': ['MTOR', 'SMAD3', 'TP53'],
#  'Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=O)COc1ccccc1[N+](=O)[O-]': ['MTOR', 'TP53'],
#  'Nc1nc2ccc(Cl)cc2c2nc(-c3ccco3)nn12': ['MTOR'],
#  'C=CCc1cccc(C=NNC(=O)CN2CCN(Cc3ccccc3)CC2)c1O': ['MTOR'],
#  'CS(=O)(=O)N1CCN(Cc2cc3nc(-c4cccc5[nH]ncc45)nc(N4CCOCC4)c3s2)CC1': ['MTOR',
#   'PIK3CA'],
#  'COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1': ['MTOR'],
#  'FC(F)c1nc2ccccc2n1-c1nc(N2CCOCC2)nc(N2CCOCC2)n1': ['MTOR', 'PIK3CA'],
#  'Nc1nc(N)c2nc(-c3cccc(O)c3)c(-c3cccc(O)c3)nc2n1': ['MTOR', 'PIK3CA'],
#  'Nc1ccc(-c2ccc3ncc4ccc(=O)n(-c5cccc(C(F)(F)F)c5)c4c3c2)cn1': ['MTOR',
#   'PIK3CA'],
#  'COC(=O)Nc1ccc(-c2nc(N3CCOCC3)c3cnn(C4CCN(C(=O)OC)CC4)c3n2)cc1': ['MTOR',
#   'PIK3CA'],
#  'OCCCNc1cc(-c2ccnc(Nc3cccc(Cl)c3)n2)ccn1': ['MTOR', 'SMAD3', 'TP53'],
#  'Nc1cc(C(F)(F)F)c(-c2cc(N3CCOCC3)nc(N3CCOCC3)n2)cn1': ['MTOR', 'PIK3CA'],
#  'O=C1c2ccccc2C(=O)c2c(NCCc3ccc(O)cc3)ccc(NCCc3ccc(O)cc3)c21': ['MTOR'],
#  'CC(C)n1nc(-c2cc3cc(O)ccc3[nH]2)c2c(N)ncnc21': ['MTOR', 'PIK3CA'],
#  'Cc1cc(C(C)Nc2ccccc2)c2nc(N3CCOCC3)cc(=O)n2c1': ['PIK3CA'],
#  'Cc1ccc(S(=O)(=O)Nc2nc3ccccc3nc2Nc2ccc3nsnc3c2)cc1': ['PIK3CA'],
#  'COc1ccc2c(c1OC)N=C(NC(=O)c1cccnc1)N1CCN=C21': ['PIK3CA'],
#  'COc1ccccc1N1CCN(CC(O)COc2cccc3ccccc23)CC1': ['SMAD3'],
#  'CCC(=O)NC(c1ccco1)c1cc(Br)c2cccnc2c1O': ['SMAD3'],
#  'CC[N+](C)(CC)CCOC(=O)C(O)(c1ccccc1)C1CCCCC1': ['SMAD3'],
#  'COc1ccc(OC)c(-c2nnc3n2N=C(c2ccc(OC)c(OC4CCOC4)c2)CS3)c1': ['SMAD3'],
#  'NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl': ['SMAD3'],
#  'COc1ccc(C2CC(c3ccccc3)=NN2c2ccc(S(N)(=O)=O)cc2)cc1': ['SMAD3'],
#  'Cc1ccc(S(=O)(=O)C(c2ccccc2)c2c(C)noc2C)cc1': ['SMAD3'],
#  'Cc1ccccc1C(OCCN(C)C)c1ccccc1': ['SMAD3'],
#  'CC(=O)NC(c1ccco1)c1cc(Cl)c2cccnc2c1O': ['SMAD3'],
#  'CC(=O)NC(c1cccs1)c1cc(Br)c2cccnc2c1O': ['SMAD3'],
#  'COc1ccc(N(C(=O)CCl)C(C(=O)NC2CCCCC2)c2cccnc2)cc1': ['SMAD3'],
#  'O=C(NC1CCCCC1)C(c1cccnc1)N(C(=O)CCl)c1cccc(Cl)c1': ['SMAD3'],
#  'O=C(c1ccc(F)cc1)C(CN1CCOCC1)c1ccccc1': ['SMAD3'],
#  'COc1ccc(OC)c(C(O)CNC(=O)CN)c1': ['SMAD3'],
#  'Cc1cc(Cl)ccc1OC(C)C(=O)Nc1ccc(C(=O)Nc2ccccc2C(=O)O)cc1': ['SMAD3'],
#  'COc1ccc(C2=Nn3c(nnc3-c3ccccc3OC)SC2)cc1OC1CCOC1': ['SMAD3'],
#  'CC1Cc2ccccc2N1NC(=O)c1ccc(Cl)c(S(N)(=O)=O)c1': ['SMAD3'],
#  'CC(Cc1ccc(O)cc1)NCC(O)c1cc(O)cc(O)c1': ['SMAD3'],
#  'Cc1ccc(CSc2nnc(-c3cccc4ccccc34)o2)cc1': ['SMAD3'],
#  'Cc1cc(NC(=O)CS(=O)(=O)c2cn(Cc3cccc(Br)c3)c3ccccc23)no1': ['SMAD3'],
#  'CC(=O)c1cccc(-c2csc3ncnc(Sc4nnnn4C)c23)c1': ['SMAD3'],
#  'COc1ccc(OC)c(-c2nnc3n2N=C(c2ccc(OC)c(OC)c2)CS3)c1': ['SMAD3'],
#  'CCn1c(=O)c([N+](=O)[O-])c(Cl)c2ccccc21': ['SMAD3'],
#  'CC(=O)Nc1ccc(CNc2ncnc3ccc(-c4c(C)noc4C)cc23)cc1': ['SMAD3'],
#  'COc1cccc(Nc2ccc(N3CCCCC3)cc2)c1OC': ['SMAD3', 'TP53'],
#  'COc1cc(N)c(Cl)cc1C(=O)NC1CCN(Cc2ccccc2)CC1': ['SMAD3'],
#  'COc1cccc(CNc2ncnc3ccc(-c4c(C)noc4C)cc23)c1': ['SMAD3', 'TP53'],
#  'O=C(CSc1nc2ccccc2c(=O)n1-c1ccc(Cl)c(Cl)c1)Nc1ccc2c(c1)CCC2': ['SMAD3'],
#  'Cn1nnnc1Sc1ncnc2scc(-c3cc4ccccc4o3)c12': ['SMAD3'],
#  'COc1ccc(C=C2SC(=S)N(CCCC(=O)Nc3ccc(C(=O)O)c(O)c3)C2=O)cc1OC': ['SMAD3'],
#  'CN(Cc1ccco1)c1ncnc2ccc(-c3ccc4c(ccn4C)c3)cc12': ['SMAD3'],
#  'Cc1cccc(NS(=O)(=O)c2ccc3c(c2)CCC(=O)N3)c1': ['SMAD3'],
#  'Cc1cc(C)c2nc(-c3ccccn3)cc(C(=O)Nc3ccc(S(=O)(=O)Nc4cc(C)on4)cc3)c2c1': ['SMAD3'],
#  'Cc1ccc(Cl)c(Cn2cnc3c(cnn3C(C)(C)C)c2=O)c1F': ['SMAD3', 'TP53'],
#  'O=C(c1ccc(Cl)cc1)N1CCN(c2ccnc3cc(Cl)ccc23)CC1': ['SMAD3'],
#  'CC(=O)Nc1nc(-c2ccccc2)nc(-c2ccccc2OC(C)=O)n1': ['SMAD3'],
#  'CC(=O)c1ccc2c(c1)N(CCCN(C)C)c1ccccc1S2': ['SMAD3'],
#  'Cc1ccc(S(=O)(=O)OCC(=O)Nc2ccc(C(=O)O)c(O)c2)cc1': ['SMAD3'],
#  'Oc1ccc(CNc2ccccc2F)c2cccnc12': ['SMAD3'],
#  'c1nc(NCc2ccc3c(c2)OCO3)c2cc(-c3ccc4c(c3)OCCO4)ccc2n1': ['SMAD3'],
#  'CC(=O)N1CCN(c2ccc(NCc3ccc(Br)o3)cc2)CC1': ['SMAD3'],
#  'C=CCn1c(SCC(=O)c2ccc(O)c(O)c2)nnc1-c1cccc(Cl)c1': ['SMAD3'],
#  'O=C(CCCN1CCC2(CC1)C(=O)NCN2c1ccccc1)c1ccc(F)cc1': ['SMAD3', 'TP53'],
#  'COc1cccc(-c2csc3ncnc(Sc4nnnn4C)c23)c1': ['SMAD3'],
#  'COc1ccc(OC)c(-c2nnc3n2N=C(c2ccc(OC)c(OC4CCCC4)c2)CS3)c1': ['SMAD3'],
#  'Cc1cccc(CNc2ncnc3ccc(-c4ccoc4)cc23)c1': ['SMAD3'],
#  'Cn1cc(C2=C(c3ccc(Cl)cc3Cl)C(=O)NC2=O)c2ccccc21': ['SMAD3'],
#  'Cc1cc2nc(NCCCO)n(CC(=O)c3cc(C(C)(C)C)c(O)c(C(C)(C)C)c3)c2cc1C': ['SMAD3'],
#  'OCc1ccc(-c2nn(Cc3ccccc3)c3ccccc23)o1': ['SMAD3'],
#  'Oc1c(CN2CCCCC2)cc(COCc2ccccc2)c2cccnc12': ['SMAD3'],
#  'O=C(NCCCN1CCOCC1)c1sc2cc([N+](=O)[O-])ccc2c1Cl': ['SMAD3'],
#  'Cn1nnnc1Sc1ncnc2scc(-c3cccc(S(C)(=O)=O)c3)c12': ['SMAD3'],
#  'CCCCn1c(O)c(N=Nc2ccccc2O)c2ccccc21': ['SMAD3'],
#  'COc1ccc(C(=O)NCc2cccnc2)cc1C(=O)NCc1cccnc1': ['SMAD3'],
#  'CCCCOc1ccc(Cl)cc1Nc1nc(NCCO)nc(N2CCCC2)n1': ['SMAD3'],
#  'O=C(c1ccc2c(c1)OCCO2)N1CCN(S(=O)(=O)c2c(F)cccc2F)CC1': ['SMAD3'],
#  'Oc1c(CN2CCCC2)cc(COCc2ccccc2)c2cccnc12': ['SMAD3'],
#  'Cc1cccc(C)c1NC(=O)c1ccc(-c2cc(F)ccc2F)o1': ['SMAD3'],
#  'O=S(=O)(c1ccc2c(c1)OCCO2)N1CCN(S(=O)(=O)c2c(F)cc(F)cc2F)CC1': ['SMAD3'],
#  'O=C(c1ccccn1)N(Cc1ccco1)C1(C(=O)Nc2ccc(Br)cc2)CCCCC1': ['SMAD3'],
#  'Cn1nc(-c2ccccn2)nc2c(=O)n(C)c(=O)nc1-2': ['SMAD3'],
#  'COc1ccccc1C(=O)OCC#CCSc1nnc(-c2cccc3ccccc23)o1': ['SMAD3'],
#  'CC(=Cc1ccccc1)C=C1SC(=S)N(CCCC(=O)Nc2ccc(C(=O)O)c(O)c2)C1=O': ['SMAD3'],
#  'Cc1ccnc(NC(=O)CCCOc2cc(=O)n(C)c3ccccc23)c1': ['SMAD3'],
#  'CCN(CC)CCOC(=O)C(O)(c1ccccc1)c1ccccc1': ['SMAD3'],
#  'OCCN(CCO)c1nc(N2CCCCC2)c2nc(N(CCO)CCO)nc(N3CCCCC3)c2n1': ['SMAD3'],
#  'COc1cccc(C(=O)C(C#N)=C(SC)SC)c1': ['SMAD3'],
#  'Cc1cccc(Nc2nc(NCCO)nc(N3CCCC3)n2)c1': ['SMAD3'],
#  'N#CCCSCc1ccc2oc(C(=O)O)cc2c1': ['SMAD3'],
#  'Cc1ccc(N(CC2=NCCN2)c2cccc(O)c2)cc1': ['SMAD3'],
#  'CCN(CC)Cc1cc(Nc2ccnc3cc(Cl)ccc23)ccc1O': ['SMAD3'],
#  'COc1cccc(-c2nc(-c3ccc(NC(=O)Cc4ccccc4OC)cc3)no2)c1': ['SMAD3'],
#  'OCC1OC(n2cnc3c(NCc4ccco4)ncnc32)C(O)C1O': ['SMAD3'],
#  'Cc1ccc(S(=O)(=O)NCc2ccc(C(=O)NCCN(Cc3ccccc3)C(C)C)cc2)cc1': ['SMAD3'],
#  'O=S(=O)(Nc1ccc(C(O)(C(F)(F)F)C(F)(F)F)cc1)c1ccc(Cl)c2nonc12': ['SMAD3'],
#  'C=CC(=O)Nc1cccc(Nc2nc(NC3CCC(N(C)C)CC3)nc3c2ncn3C(C)C)c1': ['SMAD3'],
#  'CCCCC1C(=O)N(c2ccccc2)N(c2ccc(O)cc2)C1=O': ['SMAD3'],
#  'O=S(=O)(CC(CN1CCCCC1)N1CCCCC1)c1ccccc1': ['SMAD3'],
#  'CC(Cc1cccc(C(F)(F)F)c1)NCCOC(=O)c1ccccc1': ['SMAD3'],
#  'C[N+](C)(CCOc1ccccc1)Cc1ccccc1': ['SMAD3'],
#  'Nc1nc(S)c2ncn(C3OC(CO)C(O)C3O)c2n1': ['SMAD3'],
#  'CCCCC1(COC(=O)CCC(=O)O)C(=O)N(c2ccccc2)N(c2ccccc2)C1=O': ['SMAD3'],
#  'Nc1cc(C(Cl)=C(Cl)Cl)c(S(N)(=O)=O)cc1S(N)(=O)=O': ['SMAD3'],
#  'CCCCOc1cc(C(=O)NCCN(CC)CC)c2ccccc2n1': ['SMAD3'],
#  'O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1': ['TP53'],
#  'COc1ccc(C2=Nn3c(nnc3-c3ccccc3Cl)SC2)cc1OC1CCOC1': ['TP53'],
#  'CCN(CC)CCCC(C)Nc1c2ccc(Cl)cc2nc2ccc(OC)cc12': ['TP53'],
#  'CC(C)C(=O)NC(c1ccco1)c1ccc2cccnc2c1O': ['TP53'],
#  'CCOC(=O)C1C(COCCN)=NC(C)=C(C(=O)OC)C1c1ccccc1Cl': ['TP53'],
#  'CNC(C)C(=O)NC(C(=O)N1CCCC1C(=O)Nc1ccc2ncccc2c1)C(C)C': ['TP53'],
#  'NC(=O)c1ncn(C2OC(CO)C(O)C2O)c1N': ['TP53'],
#  'CCCN(CCC)c1ncnc2c1cnn2-c1ccc(OC)cc1': ['TP53'],
#  'CC(=O)Nc1ccc(NC(=S)NC(=O)c2ccc(C(C)(C)C)cc2)cc1': ['TP53'],
#  'c1cc(CN2CCCCC2)cc(OCCCNc2nc3ccccc3s2)c1': ['TP53'],
#  'CC[N+](C)(CC)CCOC(=O)C1c2ccccc2Oc2ccccc21': ['TP53'],
#  'CCCCCCNC(=O)n1cc(F)c(=O)[nH]c1=O': ['TP53'],
#  'CC(C)c1ccccc1S(=O)(=O)c1cc(N)c2ncccc2c1[N+](=O)[O-]': ['TP53'],
#  'COC(=O)Nc1nc2cc(C(=O)c3cccs3)ccc2[nH]1': ['TP53'],
#  'O=C1C(=O)N(Cc2ccc(Cl)c(Cl)c2)c2ccccc21': ['TP53'],
#  'COc1ccccc1N1CCN(CCCCNC(=O)c2ccc3ccccc3c2)CC1': ['TP53'],
#  'Cc1cccnc1NC(=S)NC(=O)c1cncc(Br)c1': ['TP53'],
#  'COc1ccc(NC(=O)c2ccc(-c3ccc(-c4noc(C)n4)cc3C)cc2)cc1OCCN(C)C': ['TP53'],
#  'O=C(O)c1ccc2nc(-c3ccccc3)c(-c3ccccc3)nc2c1': ['TP53'],
#  'CCCCNc1c(C(=O)OCC)c(C)nc2c1cnn2CC': ['TP53'],
#  'Cn1ccc2cc3c(cc21)CCN3C(=O)Nc1cccnc1': ['TP53'],
#  'CC(=O)Oc1ccc(C(c2ccc(OC(C)=O)cc2)c2ccccn2)cc1': ['TP53'],
#  'Cc1ccc(-n2nc3ccc(NC(=O)COc4ccccc4C)cc3n2)cc1': ['TP53'],
#  'OC(c1cc(C(F)(F)F)nc2c(C(F)(F)F)cccc12)C1CCCCN1': ['TP53'],
#  'CCOC(=O)C1(c2ccccc2)CCN(CCC(C#N)(c2ccccc2)c2ccccc2)CC1': ['TP53'],
#  'O=C(c1ccc(F)cc1)C1CCN(CCn2c(=O)[nH]c3ccccc3c2=O)CC1': ['TP53'],
#  'c1ccc(CCCN2CCN(CCOC(c3ccccc3)c3ccccc3)CC2)cc1': ['TP53'],
#  'COC(=O)Nc1nc2ccc(Sc3ccccc3)cc2[nH]1': ['TP53'],
#  'CCCCn1c(CN2CCN(c3cccc(Cl)c3)CC2)nc2c1c(=O)n(C)c(=O)n2C': ['TP53'],
#  'CN(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc1': ['TP53'],
#  'Cc1ccc(C(=O)Cn2c3c(sc2=N)CCCC3)cc1': ['TP53'],
#  'Cc1ccc(NC(=O)c2cccc(N(C)C)c2)cc1NC(=O)c1ccc(O)cc1': ['TP53'],
#  'Cc1oncc1C(=O)Nc1ccc(C(F)(F)F)cc1': ['TP53'],
#  'Cn1cc(C2=C(c3cn(C4CCN(Cc5ccccn5)CC4)c4ccccc34)C(=O)NC2=O)c2ccccc21': ['TP53'],
#  'Nc1nc2c(cnn2CCc2ccccc2)c2nc(-c3ccco3)nn12': ['TP53'],
#  'Cc1ccc(OCCn2c(CCNC(=O)C3CCCCC3)nc3ccccc32)cc1': ['TP53'],
#  'Cc1cc(C)n(-c2nc(NCCCO)c3c4c(sc3n2)CCCC4)n1': ['TP53'],
#  'CCNC(=O)CCc1nc(-c2ccc(C(C)(C)C)cc2)no1': ['TP53'],
#  'CN1CCN(Cc2cc(COCc3ccccc3)c3cccnc3c2O)CC1': ['TP53'],
#  'CC(=O)Oc1ccccc1C(=O)Nc1ncc([N+](=O)[O-])s1': ['TP53'],
#  'CC(C)(C)NCC(O)c1cc(Cl)c(N)c(Cl)c1': ['TP53'],
#  'Clc1ccc(COC(Cn2ccnc2)c2ccc(Cl)cc2Cl)c(Cl)c1': ['TP53'],
#  'CCN(CC)CCNc1ccc(CO)c2sc3ccccc3c(=O)c12': ['TP53'],
#  'CN(C)c1nc(N)c(C(=O)Nc2cccnc2)nc1Cl': ['TP53']}

# %%
# models = ['aae', 'vae', 'wae']
models = ['aae']

# proteins = ['AKT1', 'AKT2', 'AURKB', 'EGFR', 'PIK3CA', 'SMAD3', 'HDAC1', 'TP53', 'MTOR']
proteins = ['AKT1']
for model in models:
    for pr in proteins:
        log_path = os.path.join('logs/' + model, pr)
        out_path = os.path.join('poses/' + model, pr)
        os.makedirs(log_path, exist_ok=True)
        os.makedirs(out_path, exist_ok=True)

# %%
# test_data = {k: inv_meta_data[k] for k in list(inv_meta_data.keys())[:5]}
# test_data
# Out:
# {'CS(=O)c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)cc1': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'EGFR',
#   'MTOR'],
#  'Cn1cc(C2=C(c3cn(CCCSC(=N)N)c4ccccc34)C(=O)NC2=O)c2ccccc21': ['AKT1',
#   'SMAD3'],
#  'CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1': ['AKT1', 'AKT2', 'AURKB'],
#  'O=c1cc(N2CCOCC2)oc2c(-c3ccccc3)cccc12': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'MTOR',
#   'PIK3CA',
#   'TP53'],
#  'O=C1NC(=O)C(c2c[nH]c3ccccc23)=C1c1c[nH]c2ccccc12': ['AKT1',
#   'AKT2',
#   'AURKB',
#   'MTOR']}

# %%
# for smi in test_data.keys():
#     escape_smi = re.sub(r'([()])', r'\\\1', smi)
#     print(escape_smi)
# Out:
# CS\(=O\)c1ccc\(-c2nc\(-c3ccc\(F\)cc3\)c\(-c3ccncc3\)[nH]2\)cc1
# Cn1cc\(C2=C\(c3cn\(CCCSC\(=N\)N\)c4ccccc34\)C\(=O\)NC2=O\)c2ccccc21
# CCC\(CO\)Nc1nc\(NCc2ccccc2\)c2ncn\(C\(C\)C\)c2n1
# O=c1cc\(N2CCOCC2\)oc2c\(-c3ccccc3\)cccc12
# O=C1NC\(=O\)C\(c2c[nH]c3ccccc23\)=C1c1c[nH]c2ccccc12

# %%
for model in models:
    for ref_smi, proteins in tqdm(inv_meta_data.items()):
        escape_smi = re.sub(r'([()])', r'\\\1', ref_smi)
        for pr in proteins:
            protein_file = 'protein/' + pr + '.pdb'
            # ligand_file = os.path.join('ligand/' + model, escape_smi + '.sdf')
            ligand_path = os.path.join('ligand/' + model, ref_smi)
            for filename in os.listdir(ligand_path):
                ligand_file = os.path.join(ligand_path, filename)
            log_file = os.path.join('logs/' + model, pr, escape_smi + '.log')
            out_file = os.path.join('poses/' + model, pr, escape_smi + '.sdf.gz')
            # !gnina -r {protein_file} -l {ligand_file} --autobox_ligand {protein_file} -o {out_file} --exhaustiveness 16 --log {log_file} -q
# Out:
#   0%|                                                                                                                                                                              | 0/238 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 14
#      11 os.makedirs(log_path, exist_ok=True)
#      12 os.makedirs(out_path, exist_ok=True)
# ---> 14 for filename in os.listdir(ligand_path):
#      15     ligand_file = os.path.join(ligand_path, filename)
#      16     generated_smi = filename.split('.')[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ligand/aae/CS(=O)c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc3)[nH]2)cc1'

# %%
# !gnina -r protein/AKT1.pdb -l ligand/wae/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.sdf --autobox_ligand protein/AKT1.pdb -o poses/wae/AKT1/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.sdf.gz --exhaustiveness 16 --log logs/wae/AKT1/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.log
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `gnina -r protein/AKT1.pdb -l ligand/wae/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.sdf --autobox_ligand protein/AKT1.pdb -o poses/wae/AKT1/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.sdf.gz --exhaustiveness 16 --log logs/wae/AKT1/CCC(CO)Nc1nc(NCc2ccccc2)c2ncn(C(C)C)c2n1.log'
